# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# from sklearn.decomposition import PCA

from lib import readfile

# %%
nba = readfile(file="nba-teams-2017.csv")

# %%
from lib import lib_describe

# %%
lib_describe(nba)
# Out:
#        games_played       wins     losses   win_prop    minutes      points  \
# count          30.0  30.000000  30.000000  30.000000  30.000000   30.000000
# mean           82.0  41.000000  41.000000   0.499967  48.316667  105.590000
# std             0.0  11.188048  11.188048   0.136448   0.131525    4.128901
# min            82.0  20.000000  15.000000   0.244000  48.100000   97.900000
# 25%            82.0  32.250000  31.500000   0.393000  48.200000  102.975000
# 50%            82.0  41.000000  41.000000   0.500000  48.300000  105.000000
# 75%            82.0  50.500000  49.750000   0.616000  48.400000  107.850000
# max            82.0  67.000000  62.000000   0.817000  48.600000  115.900000
#
#        field_goals  field_goals_attempted  field_goals_prop    points3  ...  \
# count    30.000000              30.000000          30.00000  30.000000  ...
# mean     39.050000              85.416667          45.72000   9.650000  ...
# ...

# %%
lib_describe(nba).loc["mean", "wins"]
# Out:
# 41.0

# %%
fig, ax = plt.subplots(figsize=(8, 8))
ax.scatter(x=nba["wins"], y=nba["points"], s=60, alpha=0.7, edgecolors="k")
    
a, b = np.polyfit(nba["wins"], nba["points"], deg=1)
xseq = np.linspace(0, 80, num=100)
ax.plot(xseq, b+a*xseq, color="k", lw=2.5)
ax.set_xlabel("Wins")
ax.set_ylabel("Points")
fig.show()
